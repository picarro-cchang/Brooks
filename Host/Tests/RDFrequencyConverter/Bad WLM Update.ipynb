# %%
from numpy import load

for seq in [3]:
    data = load('file_%d_vl_2.npz' % seq)
    figure(1); plot(data['waveNumberSetpoints'], data['thetaShifted'], 'o')
    figure(2); plot(data['waveNumberSetpoints'], data['pztDev'], 'o')
    figure(3); plot(data['waveNumberSetpoints'], data['thetaCal'], 'o')

# %%
fsr = 0.0202527
fCH4 = 6057.090

[fCH4 + i*fsr for i in range(-6,9)]
# Out:
# [6056.9684838,
#  6056.9887365,
#  6057.0089892000005,
#  6057.0292419,
#  6057.0494946,
#  6057.0697473,
#  6057.09,
#  6057.1102527,
#  6057.1305054,
#  6057.1507581000005,
#  6057.1710108,
#  6057.1912635,
#  6057.2115162,
#  6057.2317689,
#  6057.2520216]
